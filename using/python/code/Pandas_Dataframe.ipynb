# %% [markdown]
# # Pandas - DATAFRAME

# %%
import pandas as pd

# %%
import numpy as np

# %% [markdown]
# ### DataFrame is a tabular data structure that contain rows and columns, rows will have index and columns can have meaningful data

# %% [markdown]
# #### let's look at some examples of creating a dataframe, using numpy arrays, lists, dictionaries etc and directly.

# %%
temp = np.random.randint(low = 20, high = 100, size = [20,])

# %%
name = np.random.choice(['Mumbai', 'Delhi', 'Chennai', "Kolkata", 'Bangaluru'], 20)
random = np.random.choice([10,20,30,40,50], 20)

# %% [markdown]
# #### Now we are going to zip all the above variables into a list

# %%
a_zp = list(zip(temp, name, random))

# %%
a_zp
# Out:
# [(38, 'Mumbai', 40),
#  (36, 'Bangaluru', 50),
#  (89, 'Kolkata', 50),
#  (89, 'Bangaluru', 50),
#  (68, 'Chennai', 10),
#  (57, 'Kolkata', 10),
#  (28, 'Bangaluru', 40),
#  (96, 'Chennai', 10),
#  (87, 'Mumbai', 10),
#  (86, 'Kolkata', 30),
#  (47, 'Mumbai', 30),
#  (71, 'Chennai', 50),
#  (61, 'Mumbai', 10),
#  (62, 'Delhi', 20),
#  (38, 'Mumbai', 30),
#  (93, 'Chennai', 20),
#  (51, 'Kolkata', 50),
#  (60, 'Delhi', 40),
#  (58, 'Bangaluru', 30),
#  (97, 'Chennai', 50)]

# %% [markdown]
# #### Creating a Dataframe from above list

# %%
a_df = pd.DataFrame(data = a_zp, columns = ['temp', 'name', 'random'])

# %%
a_df
# Out:
#     temp       name  random
# 0     38     Mumbai      40
# 1     36  Bangaluru      50
# 2     89    Kolkata      50
# 3     89  Bangaluru      50
# 4     68    Chennai      10
# 5     57    Kolkata      10
# 6     28  Bangaluru      40
# 7     96    Chennai      10
# 8     87     Mumbai      10
# 9     86    Kolkata      30
# 10    47     Mumbai      30
# 11    71    Chennai      50
# 12    61     Mumbai      10
# 13    62      Delhi      20
# 14    38     Mumbai      30
# 15    93    Chennai      20
# 16    51    Kolkata      50
# 17    60      Delhi      40
# 18    58  Bangaluru      30
# 19    97    Chennai      50

# %%
type(a_df)
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# #### how to create Dataframe from dictionaries

# %%
a_df = pd.DataFrame({'random':random, 'name':name, 'temp':temp})

# %%
a_df
# Out:
#     random       name  temp
# 0       40     Mumbai    38
# 1       50  Bangaluru    36
# 2       50    Kolkata    89
# 3       50  Bangaluru    89
# 4       10    Chennai    68
# 5       10    Kolkata    57
# 6       40  Bangaluru    28
# 7       10    Chennai    96
# 8       10     Mumbai    87
# 9       30    Kolkata    86
# 10      30     Mumbai    47
# 11      50    Chennai    71
# 12      10     Mumbai    61
# 13      20      Delhi    62
# 14      30     Mumbai    38
# 15      20    Chennai    93
# 16      50    Kolkata    51
# 17      40      Delhi    60
# 18      30  Bangaluru    58
# 19      50    Chennai    97

# %% [markdown]
# ##### There are another ways to create a dataframes from various sources such as CSV, text files, Excel sheets etc

# %% [markdown]
# #### first let's perform some minor operations over dataframe

# %%
a_df.head()  # Outputs first 5 rows of the dataframe
# Out:
#    random       name  temp
# 0      40     Mumbai    38
# 1      50  Bangaluru    36
# 2      50    Kolkata    89
# 3      50  Bangaluru    89
# 4      10    Chennai    68

# %%
a_df.tail()  # Outputs last 5 rows of the dataframe
# Out:
#     random       name  temp
# 15      20    Chennai    93
# 16      50    Kolkata    51
# 17      40      Delhi    60
# 18      30  Bangaluru    58
# 19      50    Chennai    97

# %%
a_df.shape # check dimensions of the dataframe
# Out:
# (20, 3)

# %%
a_df.columns # Checking columns present in the Dataframe,
# Out:
# Index(['random', 'name', 'temp'], dtype='object')

# %% [markdown]
# #### Retrieving all values of a particular column present in a dataframe

# %%
a_df.name # just mention the column-name we desire to retrieve values from
# Out:
# 0        Mumbai
# 1     Bangaluru
# 2       Kolkata
# 3     Bangaluru
# 4       Chennai
# 5       Kolkata
# 6     Bangaluru
# 7       Chennai
# 8        Mumbai
# 9       Kolkata
# 10       Mumbai
# 11      Chennai
# 12       Mumbai
# 13        Delhi
# 14       Mumbai
# 15      Chennai
# 16      Kolkata
# 17        Delhi
# 18    Bangaluru
# 19      Chennai
# Name: name, dtype: object

# %%
a_df['random'] # more common way for getting values of a particular column
# Out:
# 0     40
# 1     50
# 2     50
# 3     50
# 4     10
# 5     10
# 6     40
# 7     10
# 8     10
# 9     30
# 10    30
# 11    50
# 12    10
# 13    20
# 14    30
# 15    20
# 16    50
# 17    40
# 18    30
# 19    50
# Name: random, dtype: int64

# %% [markdown]
# ## Statistical Information (summary statistics like in R)

# %%
a_df.describe()
# Out:
#           random       temp
# count  20.000000  20.000000
# mean   31.500000  65.600000
# std    15.985191  22.046363
# min    10.000000  28.000000
# 25%    17.500000  50.000000
# 50%    30.000000  61.500000
# 75%    50.000000  87.500000
# max    50.000000  97.000000

# %% [markdown]
# #### statistical information of a particular column

# %%
a_df.temp.describe() # or a_df['temp'].describe()
# Out:
# count    20.000000
# mean     65.600000
# std      22.046363
# min      28.000000
# 25%      50.000000
# 50%      61.500000
# 75%      87.500000
# max      97.000000
# Name: temp, dtype: float64

# %% [markdown]
# #### General information about a dataframe using .info() function

# %%
a_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20 entries, 0 to 19
# Data columns (total 3 columns):
# random    20 non-null int64
# name      20 non-null object
# temp      20 non-null int64
# dtypes: int64(2), object(1)
# memory usage: 560.0+ bytes

# %% [markdown]
# #### Outputting a dataframe in a different format / way

# %%
a_df.values
# Out:
# array([[40, 'Mumbai', 38],
#        [50, 'Bangaluru', 36],
#        [50, 'Kolkata', 89],
#        [50, 'Bangaluru', 89],
#        [10, 'Chennai', 68],
#        [10, 'Kolkata', 57],
#        [40, 'Bangaluru', 28],
#        [10, 'Chennai', 96],
#        [10, 'Mumbai', 87],
#        [30, 'Kolkata', 86],
#        [30, 'Mumbai', 47],
#        [50, 'Chennai', 71],
#        [10, 'Mumbai', 61],
#        [20, 'Delhi', 62],
#        [30, 'Mumbai', 38],
#        [20, 'Chennai', 93],
#        [50, 'Kolkata', 51],
#        [40, 'Delhi', 60],
#        [30, 'Bangaluru', 58],
#        [50, 'Chennai', 97]], dtype=object)

# %% [markdown]
# ### IF we look at the dataframe above we see the index is generated automatically for us, but if want to change / or convert a column to be as an index for our dataframe, this is possible using set_index() function

# %%
a_df.set_index('temp')
# Out:
#       random       name
# temp
# 38        40     Mumbai
# 36        50  Bangaluru
# 89        50    Kolkata
# 89        50  Bangaluru
# 68        10    Chennai
# 57        10    Kolkata
# 28        40  Bangaluru
# 96        10    Chennai
# 87        10     Mumbai
# 86        30    Kolkata
# 47        30     Mumbai
# 71        50    Chennai
# 61        10     Mumbai
# 62        20      Delhi
# 38        30     Mumbai
# 93        20    Chennai
# 51        50    Kolkata
# 60        40      Delhi
# 58        30  Bangaluru
# 97        50    Chennai

# %% [markdown]
# ##### The above change is Temporary, let's output a_df, we see

# %%
a_df
# Out:
#     random       name  temp
# 0       40     Mumbai    38
# 1       50  Bangaluru    36
# 2       50    Kolkata    89
# 3       50  Bangaluru    89
# 4       10    Chennai    68
# 5       10    Kolkata    57
# 6       40  Bangaluru    28
# 7       10    Chennai    96
# 8       10     Mumbai    87
# 9       30    Kolkata    86
# 10      30     Mumbai    47
# 11      50    Chennai    71
# 12      10     Mumbai    61
# 13      20      Delhi    62
# 14      30     Mumbai    38
# 15      20    Chennai    93
# 16      50    Kolkata    51
# 17      40      Delhi    60
# 18      30  Bangaluru    58
# 19      50    Chennai    97

# %% [markdown]
# ### To make a change Permanent to a dataframe, as in the case with .set_index() above, we need to supply / add inplace parameter to the code, by default inplace = False

# %%
a_df.set_index('temp', inplace = True)

# %%
a_df
# Out:
#       random       name
# temp
# 38        40     Mumbai
# 36        50  Bangaluru
# 89        50    Kolkata
# 89        50  Bangaluru
# 68        10    Chennai
# 57        10    Kolkata
# 28        40  Bangaluru
# 96        10    Chennai
# 87        10     Mumbai
# 86        30    Kolkata
# 47        30     Mumbai
# 71        50    Chennai
# 61        10     Mumbai
# 62        20      Delhi
# 38        30     Mumbai
# 93        20    Chennai
# 51        50    Kolkata
# 60        40      Delhi
# 58        30  Bangaluru
# 97        50    Chennai

# %% [markdown]
# #### Sort the dataframe by index values

# %%
a_df.sort_index(axis = 0, ascending = True)
# Out:
#       random       name
# temp
# 28        40  Bangaluru
# 36        50  Bangaluru
# 38        40     Mumbai
# 38        30     Mumbai
# 47        30     Mumbai
# 51        50    Kolkata
# 57        10    Kolkata
# 58        30  Bangaluru
# 60        40      Delhi
# 61        10     Mumbai
# 62        20      Delhi
# 68        10    Chennai
# 71        50    Chennai
# 86        30    Kolkata
# 87        10     Mumbai
# 89        50  Bangaluru
# 89        50    Kolkata
# 93        20    Chennai
# 96        10    Chennai
# 97        50    Chennai

# %% [markdown]
# #### Sort the dataframe with respect to column / by column values

# %%
a_df.sort_values(by = 'random', ascending = False)
# Out:
#       random       name
# temp
# 97        50    Chennai
# 36        50  Bangaluru
# 89        50    Kolkata
# 89        50  Bangaluru
# 51        50    Kolkata
# 71        50    Chennai
# 60        40      Delhi
# 38        40     Mumbai
# 28        40  Bangaluru
# 86        30    Kolkata
# 38        30     Mumbai
# 58        30  Bangaluru
# 47        30     Mumbai
# 62        20      Delhi
# 93        20    Chennai
# 87        10     Mumbai
# 96        10    Chennai
# 61        10     Mumbai
# 57        10    Kolkata
# 68        10    Chennai

# %%
a_df.drop(['random'])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-39-1bbbe3111ca1> in <module>
# ----> 1 a_df.drop(['random'])
#
# /mnt/23950E493BF8A371/anaconda3/lib/python3.7/site-packages/pandas/core/frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3695                                            index=index, columns=columns,
#    3696                                            level=level, inplace=inplace,
# -> 3697                                            errors=errors)
#    3698
#    3699     @rewrite_axis_style_signature('mapper', [('copy', True),
#
# /mnt/23950E493BF8A371/anaconda3/lib/python3.7/site-packages/pandas/core/generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3109         for axis, labels in axes.items():
#    3110             if labels is not None:
# -> 3111                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    3112
#    3113         if inplace:
#
# /mnt/23950E493BF8A371/anaconda3/lib/python3.7/site-packages/pandas/core/generic.py in _drop_axis(self, labels, axis, level, errors)
#    3160                 labels_missing = (axis.get_indexer_for(labels) == -1).any()
#    3161                 if errors == 'raise' and labels_missing:
# -> 3162                     raise KeyError('{} not found in axis'.format(labels))
#    3163
#    3164             slicer = [slice(None)] * self.ndim
#
# KeyError: "['random'] not found in axis"

# %% [markdown]
# #### note to self: we get this error because random is a column not a row, imp to know that axis by default is 0, to drop the column we must change the axis to 1 (axis = 0 is row and when axis = 1 it is column)

# %%
a_df.drop('random', axis=1) # or we can write this like a_df.drop(['random'], axis=1)
# Out:
#            name
# temp
# 38       Mumbai
# 36    Bangaluru
# 89      Kolkata
# 89    Bangaluru
# 68      Chennai
# 57      Kolkata
# 28    Bangaluru
# 96      Chennai
# 87       Mumbai
# 86      Kolkata
# 47       Mumbai
# 71      Chennai
# 61       Mumbai
# 62        Delhi
# 38       Mumbai
# 93      Chennai
# 51      Kolkata
# 60        Delhi
# 58    Bangaluru
# 97      Chennai

# %%
#remember still not a permanent change
a_df.head()
# Out:
#       random       name
# temp
# 38        40     Mumbai
# 36        50  Bangaluru
# 89        50    Kolkata
# 89        50  Bangaluru
# 68        10    Chennai

# %% [markdown]
# ## iloc[ ] and loc[ ]  (Selecting data)

# %% [markdown]
# #### we have seen how to access element by providing indexes, similarly we can access elements of a dataframe. But a more cleaner way for achieving this is using iloc[] and loc[]

# %%
a_df.iloc[[0,1]]  # Row indexes
# Out:
#       random       name
# temp
# 38        40     Mumbai
# 36        50  Bangaluru

# %%
a_df.iloc[1:3,1]  # 1 to 3 row indexes from column index 1
# Out:
# temp
# 36    Bangaluru
# 89      Kolkata
# Name: name, dtype: object

# %% [markdown]
# #### using Boolean, True will select the value at the corresponding index and False will omit it, till we have mentioned, but after that every index for which we have not supplied any bool will be considered False automatically till the end of the dataframe and omitted

# %%
a_df.iloc[[True, False, True, True, False]]
# Out:
#       random       name
# temp
# 38        40     Mumbai
# 89        50    Kolkata
# 89        50  Bangaluru

# %% [markdown]
# ### loc[ ] , here we SELECT using the VALUES of the Index itself

# %%
a_df.loc[38]
# Out:
#       random    name
# temp
# 38        40  Mumbai
# 38        30  Mumbai

# %%
a_df.loc[[38,89,57,61]]
# Out:
#       random       name
# temp
# 38        40     Mumbai
# 38        30     Mumbai
# 89        50    Kolkata
# 89        50  Bangaluru
# 57        10    Kolkata
# 61        10     Mumbai

# %% [markdown]
# #### If we want to select values from particular columns, we can specify column names and or column range

# %%
a_df.loc[[38,89,61],['name']]
# Out:
#            name
# temp
# 38       Mumbai
# 38       Mumbai
# 89      Kolkata
# 89    Bangaluru
# 61       Mumbai

# %%
a_df.loc[[39,89,61], 'random':'name'] # index value 39 is not present in data so NaN
# Out:
#       random       name
# temp
# 39       NaN        NaN
# 89      50.0    Kolkata
# 89      50.0  Bangaluru
# 61      10.0     Mumbai

# %%
a_df.loc[[38,89,61], 'random':'name']
# Out:
#       random       name
# temp
# 38        40     Mumbai
# 38        30     Mumbai
# 89        50    Kolkata
# 89        50  Bangaluru
# 61        10     Mumbai

# %%
a_df.loc[[True, False, True, True, False, True, True], ['random']]
# Out:
#       random
# temp
# 38        40
# 89        50
# 89        50
# 57        10
# 28        40

# %% [markdown]
# ### Within loc[], we can also define some conditions

# %%
a_df.loc[a_df.name == "Mumbai"]
# Out:
#       random    name
# temp
# 38        40  Mumbai
# 87        10  Mumbai
# 47        30  Mumbai
# 61        10  Mumbai
# 38        30  Mumbai

# %% [markdown]
# #### combine condtional logic

# %%
a_df.loc[(a_df.random > 15) & (a_df.name == "Mumbai"), : ]
# Out:
#       random    name
# temp
# 38        40  Mumbai
# 47        30  Mumbai
# 38        30  Mumbai
